# %%
import os
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from pprint import pprint
import math

# %matplotlib inline

# %%
def pressure(t):
    
    a01=0.62
    a11=27.255
    a21=0
    a31=0
    
    a02=1.3167
    a12=7.0963
    a22=0
    a32=0

    a03=1.7261
    a13=0.4572
    a23=-8.442
    a33=0
    
    a04=7.8339
    a14=-40.596
    a24=60.336
    a34=0
    
    a05=-1.9927
    a15=15.686
    a25=-20.072
    a35=0
    
    a06=-3.9966
    a16=25.484
    a26=-32.035
    a36=0
    
    a07=1.9567
    a17=-3.0138
    a27=1.9561
    a37=0
    
    a08=1.1976
    a18=-0.5776
    a28=0
    a38=0
    
    R=35000000
    Cc=0.0000001
    r=50
    R_art=0.005
    PI=3.14159265359
  

    if (t<=0.0231):
        
        A=a31
        B=a21-3*Cc*R*a31
        C=2*Cc*R*(3*Cc*R*a31-a21)+a11
        D=-6*Cc**3*R**3*a31+2*Cc**2*R**2*a21-Cc*R*a11+a01
        
        G1=Cc*R*(A*t**3+B*t**2+C*t+D)#*np.exp(t/(Cc*R))
        
        A1=3*a31
        B1=2*a21-6*a31*Cc*R
        C1=6*a31*Cc**2*R**2-2*a21*Cc*R+a11
        
        G2=Cc*R*(A1*t**2+B1*t+C1)#*np.exp(t/(Cc*R))
        
        return PI*R_art**2/Cc*((1+r/R)*G1+Cc*r*G2)#*np.exp(-t/(Cc*R))           

    if(t>0.0231 and t<=0.0584):
                                             
        A=a32
        B=a22-3*Cc*R*a32
        C=2*Cc*R*(3*Cc*R*a32-a22)+a12
        D=-6*Cc**3*R**3*a32+2*Cc**2*R**2*a22-Cc*R*a12+a02
        
        G1=Cc*R*(A*t**3+B*t**2+C*t+D)#*np.exp(t/(Cc*R))
        
        A1=3*a32
        B1=2*a22-6*a32*Cc*R
        C1=6*a32*Cc**2*R**2-2*a22*Cc*R+a12 
        
        G2=Cc*R*(A1*t**2+B1*t+C1)#*np.exp(t/(Cc*R))
        
        return PI*R_art**2/Cc*((1+r/R)*G1+Cc*r*G2)#*np.exp(-t/(Cc*R)) 
        
    if (t>0.0584 and t <= 0.2926):

        A=a33
        B=a23-3*Cc*R*a33
        C=2*Cc*R*(3*Cc*R*a33-a23)+a13
        D=-6*Cc**3*R**3*a33+2*Cc**2*R**2*a23-Cc*R*a13+a03
        
        G1=Cc*R*(A*t**3+B*t**2+C*t+D)#*np.exp(t/(Cc*R))
        
        A1=3*a33
        B1=2*a23-6*a33*Cc*R
        C1=6*a33*Cc**2*R**2-2*a23*Cc*R+a13
                               
        G2=Cc*R*(A1*t**2+B1*t+C1)#*np.exp(t/(Cc*R))
        
        return PI*R_art**2/Cc*((1+r/R)*G1+Cc*r*G2)#*np.exp(-t/(Cc*R)) 
    
    if (t>0.2926 and t <= 0.3318):

        A=a34
        B=a24-3*Cc*R*a34
        C=2*Cc*R*(3*Cc*R*a34-a24)+a14
        D=-6*Cc**3*R**3*a34+2*Cc**2*R**2*a24-Cc*R*a14+a04
        
        G1=Cc*R*(A*t**3+B*t**2+C*t+D)#*np.exp(t/(Cc*R))
        
        A1=3*a34
        B1=2*a24-6*a34*Cc*R
        C1=6*a34*Cc**2*R**2-2*a24*Cc*R+a14
                               
        G2=Cc*R*(A1*t**2+B1*t+C1)#*np.exp(t/(Cc*R))
        
        return PI*R_art**2/Cc*((1+r/R)*G1+Cc*r*G2)#*np.exp(-t/(Cc*R)) 
    
    if(t>0.3318 and t <= 0.3944):

        A=a35
        B=a25-3*Cc*R*a35
        C=2*Cc*R*(3*Cc*R*a35-a25)+a15
        D=-6*Cc**3*R**3*a35+2*Cc**2*R**2*a25-Cc*R*a15+a05
        
        G1=Cc*R*(A*t**3+B*t**2+C*t+D)#*np.exp(t/(Cc*R))
        
        A1=3*a35
        B1=2*a25-6*a35*Cc*R
        C1=6*a35*Cc**2*R**2-2*a25*Cc*R+a15
                               
        G2=Cc*R*(A1*t**2+B1*t+C1)#*np.exp(t/(Cc*R))
        
        
        return PI*R_art**2/Cc*((1+r/R)*G1+Cc*r*G2)#*np.exp(-t/(Cc*R)) 

    if(t>0.3944 and t <= 0.4432):

        A=a36
        B=a26-3*Cc*R*a36
        C=2*Cc*R*(3*Cc*R*a36-a26)+a16
        D=-6*Cc**3*R**3*a36+2*Cc**2*R**2*a26-Cc*R*a16+a06
        
        G1=Cc*R*(A*t**3+B*t**2+C*t+D)#*np.exp(t/(Cc*R))
        
        A1=3*a36
        B1=2*a26-6*a36*Cc*R
        C1=6*a36*Cc**2*R**2-2*a26*Cc*R+a16
                               
        G2=Cc*R*(A1*t**2+B1*t+C1)#*np.exp(t/(Cc*R))

        
        return PI*R_art**2/Cc*((1+r/R)*G1+Cc*r*G2)#*np.exp(-t/(Cc*R)) 

    if(t>0.4432 and t <= 0.6181):

        A=a37
        B=a27-3*Cc*R*a37
        C=2*Cc*R*(3*Cc*R*a37-a27)+a17
        D=-6*Cc**3*R**3*a37+2*Cc**2*R**2*a27-Cc*R*a17+a07
        
        G1=Cc*R*(A*t**3+B*t**2+C*t+D)#*np.exp(t/(Cc*R))
        
        A1=3*a37
        B1=2*a27-6*a37*Cc*R
        C1=6*a37*Cc**2*R**2-2*a27*Cc*R+a17
                               
        G2=Cc*R*(A1*t**2+B1*t+C1)#*np.exp(t/(Cc*R))
        
        return PI*R_art**2/Cc*((1+r/R)*G1+Cc*r*G2)#*np.exp(-t/(Cc*R)) 

    if(t>0.6181 and t <= 1):

        A=a38
        B=a28-3*Cc*R*a38
        C=2*Cc*R*(3*Cc*R*a38-a28)+a18
        D=-6*Cc**3*R**3*a38+2*Cc**2*R**2*a28-Cc*R*a18+a08
        
        G1=Cc*R*(A*t**3+B*t**2+C*t+D)#*np.exp(t/(Cc*R))
        
        A1=3*a38
        B1=2*a28-6*a38*Cc*R
        C1=6*a38*Cc**2*R**2-2*a28*Cc*R+a18
                               
        G2=Cc*R*(A1*t**2+B1*t+C1)#*np.exp(t/(Cc*R))
        
        return PI*R_art**2/Cc*((1+r/R)*G1+Cc*r*G2)#*np.exp(-t/(Cc*R))                                                              
    
def velocity(t):
    
    a01=0.62
    a11=27.255
    a21=0
    a31=0
    
    a02=1.3167
    a12=7.0963
    a22=0
    a32=0

    a03=1.7261
    a13=0.4572
    a23=-8.442
    a33=0
    
    a04=7.8339
    a14=-40.596
    a24=60.336
    a34=0
    
    a05=-1.9927
    a15=15.686
    a25=-20.072
    a35=0
    
    a06=-3.9966
    a16=25.484
    a26=-32.035
    a36=0
    
    a07=1.9567
    a17=-3.0138
    a27=1.9561
    a37=0
    
    a08=1.1976
    a18=-0.5776
    a28=0
    a38=0
    
    if t<=0.0231:
        return a01+a11*t**1+a21*t**2+a31*t**3
        
    if(t>0.0231 and t <= 0.0584):
        return a02+a12*t**1+a22*t**2+a32*t**3

    if(t>0.0584 and t <= 0.2926):
        return a03+a13*t**1+a23*t**2+a33*t**3
    
    if(t>0.2926 and t <= 0.3318):
        return a04+a14*t**1+a24*t**2+a34*t**3
    
    if(t>0.3318 and t <= 0.3944):
        return a05+a15*t**1+a25*t**2+a35*t**3

    if(t>0.3944 and t <= 0.4432):
        return a06+a16*t**1+a26*t**2+a36*t**3

    if(t>0.4432 and t <= 0.6181):
        return a07+a17*t**1+a27*t**2+a37*t**3

    if(t>0.6181 and t <= 1):
        return a08+a18*t**1+a28*t**2+a38*t**3
    

heart_rate=60
pulse_time=60/heart_rate
step_size=0.01
time = np.arange(0,pulse_time+step_size,step_size)
v_profile=[]
p_profile=[]


max=int(pulse_time/step_size)



for i in range(0,max+1):
    v_profile.append(velocity(time[i]))
    
for i in range(0,max+1):
    p_profile.append(pressure(time[i]))

# %%
plt.plot(time, p_profile)
#plt.ylim(0,2)
#plt.xlim(0, 1)
plt.title('pressure profile')
plt.xlabel('time [s]')
plt.ylabel('pressure [Pa]')
# Out:
# Text(0,0.5,'pressure [Pa]')

# %%
plt.plot(time, v_profile)
plt.ylim(0,2)
plt.xlim(0, 1)
plt.title('velocity profile')
plt.xlabel('time [s]')
plt.ylabel('velocity [m/s]')
# Out:
# Text(0,0.5,'velocity [m/s]')
